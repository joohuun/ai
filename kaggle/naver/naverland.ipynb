# %%
import requests
import json
import pandas as pd
import pprint

# %%
# down_url = 'https://new.land.naver.com/api/articles/complex/8967?realEstateType=APT%3APRE&tradeType=&tag=%3A%3A%3A%3A%3A%3A%3A%3A&rentPriceMin=0&rentPriceMax=900000000&priceMin=0&priceMax=900000000&areaMin=0&areaMax=900000000&oldBuildYears&recentlyBuildYears&minHouseHoldCount&maxHouseHoldCount&showArticle=false&sameAddressGroup=false&minMaintenanceCost&maxMaintenanceCost&priceType=RETAIL&directions=&page=1&complexNo=8967&buildingNos=&areaNos=&type=list&order=rank'
down_url = 'https://new.land.naver.com/api/complexes/8967?'
r = requests.get(down_url,data={"sameAddressGroup":"false"},headers={
    "Accept-Encoding": "gzip",
    "Host": "new.land.naver.com",
    "Referer": "https://new.land.naver.com/complexes/8967?ms=37.4827637,127.0636389,16&a=APT:PRE&e=RETAIL&articleNo=2320776933",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36",
    "Authorization": "Bearer eyJzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IlJFQUxFU1RBVEUiLCJpYXQiOjE2ODQzMTE2MjcsImV4cCI6MTY4NDMyMjQyN30.2-c1AQzor7sf3Om5WJHvIfCFwxtEF6AxI_Xe54X11M0"
})
r.encoding = "utf-8-sig"
temp=json.loads(r.text)
print(temp['complexDetail'])
# Out:
# {'complexNo': '8967', 'complexName': '개포현대5차', 'cortarNo': '1168010300', 'realEstateTypeCode': 'APT', 'realEstateTypeName': '아파트', 'detailAddress': '172-3', 'roadAddress': '선릉로18길 12', 'latitude': 37.484319, 'longitude': 127.060077, 'totalHouseholdCount': 18, 'totalLeaseHouseholdCount': 0, 'permanentLeaseHouseholdCount': 0, 'nationLeaseHouseholdCount': 0, 'civilLeaseHouseholdCount': 0, 'publicLeaseHouseholdCount': 0, 'longTermLeaseHouseholdCount': 0, 'etcLeaseHouseholdCount': 0, 'highFloor': 9, 'lowFloor': 9, 'useApproveYmd': '19940222', 'totalDongCount': 1, 'maxSupplyArea': 148.38, 'minSupplyArea': 148.38, 'dealCount': 2, 'rentCount': 0, 'leaseCount': 1, 'shortTermRentCount': 0, 'isBookmarked': False, 'batlRatio': '167', 'btlRatio': '24', 'parkingPossibleCount': 23, 'parkingCountByHousehold': 1.27, 'constructionCompanyName': '현대건설(주)', 'heatMethodTypeCode': 'HT001', 'heatFuelTypeCode': 'HF001', 'pyoengNames': '148', 'address': '서울시 강남구 개포동', 'roadAddressPrefix': '서울시 강남구', 'roadZipC
# ...

# %%
import pandas as pd
apt_data=temp["complexDetail"]
pyoeng_list=apt_data["pyoengNames"].split(", ")
apt_data_pd=pd.DataFrame(data=apt_data,index=range(len(pyoeng_list)))
for i in range(len(pyoeng_list)):
    apt_data_pd.loc[i,"pyoengNames"]=pyoeng_list[i]
apt_data_pd
# Out:
#   complexNo complexName    cortarNo realEstateTypeCode realEstateTypeName  \
# 0      8967      개포현대5차  1168010300                APT                아파트
#
#   detailAddress roadAddress   latitude   longitude  totalHouseholdCount  ...  \
# 0         172-3   선릉로18길 12  37.484319  127.060077                   18  ...
#
#    btlRatio  parkingPossibleCount  parkingCountByHousehold  \
# 0        24                    23                     1.27
#
#    constructionCompanyName  heatMethodTypeCode  heatFuelTypeCode  pyoengNames  \
# 0                  현대건설(주)               HT001             HF001          148
#
#        address  roadAddressPrefix roadZipCode
# 0  서울시 강남구 개포동            서울시 강남구       06325
#
# [1 rows x 39 columns]

# %%
import matplotlib.pyplot as plt

# JSON 파일 읽기
with open('data.json', 'r') as f:
    data = json.load(f)

data = data['DATA']
info_list = []
for item in data:
    info = {
        "bjdong_cd": item['bjdong_cd'],
        "sido_nm": item['sido_nm'],
        "sigungu_nm": item['sigungu_nm'],
        "bjdong_nm": item['bjdong_nm']
    }
    info_list.append(info)

# # 결과 출력
cortarNo_list = []
for info in info_list:
    cortarNo_list.append(info['bjdong_cd'])
    # print(info['bjdong_cd'])

print(cortarNo_list)
# Out:
# ['11400', '10300', '10600', '10300', '10300', '10300', '11200', '10300', '10300', '10200', '10200', '10200', '10300', '11200', '10800', '10500', '10900', '10500', '10200', '10800', '10900', '11300', '10400', '10400', '10500', '16400', '16200', '16200', '16200', '16200', '16200', '16300', '13000', '17300', '10300', '11900', '10200', '10300', '10100', '10700', '11000', '10400', '11400', '10600', '10100', '11000', '10200', '10300', '10400', '10500', '10800', '10900', '11100', '11900', '10600', '10600', '10400', '13200', '12400', '12300', '12200', '12100', '12000', '11900', '11800', '10900', '10800', '10700', '10500', '10400', '10300', '10200', '10100', '10100', '10200', '10200', '10200', '10200', '10200', '10200', '10200', '10200', '10200', '10200', '10200', '10100', '10100', '10100', '10100', '10100', '10100', '10100', '10100', '10100', '10600', '10300', '10400', '11000', '11100', '10200', '10300', '10700', '10100', '11300', '10200', '10500', '10100', '12300', '12400', '10800', '12500'
# ...

# %%
import requests
from bs4 import BeautifulSoup
import json



def crawl_naver():
    # url = finance_url
    headers = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36"}
    url = "https://m.r114.com/?_c=memul&_m=list&_a=memul&CortarNo=1168000000&mmCode=A01001&CortarNm="
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    articles = soup.select("ul.type06_headline li")
